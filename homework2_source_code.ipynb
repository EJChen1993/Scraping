# %% [markdown]
# ## 1
# ### import article

# %%
import re, codecs
with open("/Users/yichiehchen/python file/text mining/PA-2/TMBD_news_files_2000.txt") as f:
    raw_article = f.readlines() 

#print(raw_article)

article = []
for i in raw_article:
    i = i[:-1] #remove \n
    i = i.split(" ")[:-1] #remove space
    i[0] = i[0].split("\t")[1] #remove no. and \t
    article.append(i)
    #remove \u3000
    for i in article:
        for j in i:
            if j == "\u3000":
                i.remove(j)
            
#print(article[0:3])

# %% [markdown]
# ### import stopword & punctuation

# %%
with open("/Users/yichiehchen/python file/text mining/PA-2/punctuation.txt") as p:
    raw_pun = p.readlines()
#print(raw_pun)

#remove \n
pun = []
for i in raw_pun:
    i = i[0]
    pun.append(i)

with open("/Users/yichiehchen/python file/text mining/PA-2/stopword_chinese.txt") as s:
    raw_stopword = s.readlines()
#print(raw_stopword)

#remove \n
stopword = []
for i in raw_stopword:
    i = i[:-1]
    stopword.append(i)

# %% [markdown]
# ## 2
# ### remove stopword & punctuation

# %%
final_article = []
for i in article:
    article_1 = list(filter(lambda x: x not in pun, i))
    article_2 = list(filter(lambda y: y not in stopword, article_1))
    final_article.append(article_2)
    
print(final_article[0]) 
#print(final_article[1])
#print(len(final_article))
# Out:
# ['NBAWade', '出書', '談', '爸爸', '經', '澄清', '教練', '爭執', '記者', '邵瑞峰', '綜合', '報導', '熱火', '閃電俠', 'Dwyane', 'Wade', '近日', '推出', '新書', 'A', 'Father', 'First', ':', 'How', 'My', 'Life', 'Became', 'Bigger', 'Than', 'Basketball', '特地', '送', '本', '簽名書', '給', '好兄弟', '皇帝', 'Lebron', 'James', 'Wade', '書', '除了', '大談', '爸爸', '經', '透露', '一些', '知', '熱火', '秘辛', '包括', '季後賽', '準決賽', '第三', '戰', '教練', 'Erik', 'Spoelstra', '對罵', '內幕', 'Wade', '今年', '季後賽', '面對', '溜', '馬的', '東區', '準決賽', '第三', '戰時', '比賽', '中和', 'Spoelstra', '發生', '激烈', '衝突', '板凳', '席', '破口大罵', '對方', '畫面', '甚至', '透過', '電視', '轉播', '所有', '球迷', '看到', 'Wade', '書', '解釋', '當時', '情況', '那時', '正', '飽受', '膝傷', '折磨', 'Spoelstra', '正好', '怒火', '給', '掃', 'Spoelstra', '可能', '試', '生氣', '生氣', '時候', '通常', '表現', 'Wade', '不過', '當時', '其實', '挫折', '多過', '憤怒', '帶', '挫折', '上場', '帶', '怒火', '上場', '可是', '完全', '一樣', '事', '雖然', '直言', 'Spoelstra', '當時', '激勵', '策略', '失效', '不過', 'Wade', '還是', '對於', '總教練', '推崇', '有加', '大開眼界', '學到', '身為', '冠軍', '應該', '有的', '心態', '所作所為', '除了', 'Spoelstra', 'Wade', '書', '談到', '本', '季', '魔獸', '人生', '魔術', '炒掉', '前', '熱火', '教頭', 'Stan', 'Van', 'Gundy', 'Van', 'Gundy', '教練', '種會', '一直', '叮嚀', '直到', '耳', '邊', '潛意識', '聲音', 'Wade', '總是', '歇斯底里', '風格', '就是', '永遠', '保持', '高度', '緊繃', '狀態', '不過', 'Stan', '造就', '強悍', '程度', '高度', '集中', '態度']

# %% [markdown]
# ## 3
# ### caculate TF in each document  {no.: {term:TF...}}

# %%
each_doc = {}

for i in range(1, 2001):
    each_doc[i] = {}
    for j in final_article[i-1]:
        if j not in list(each_doc[i].keys()):
            each_doc[i][j] = 1
        else:
            each_doc[i][j] += 1
print(each_doc[1])
# Out:
# {'聲音': 1, '其實': 1, '激勵': 1, '永遠': 1, 'A': 1, ':': 1, '應該': 1, '包括': 1, '邵瑞峰': 1, '近日': 1, '可是': 1, '有加': 1, 'How': 1, 'Became': 1, 'Erik': 1, '學到': 1, '還是': 1, '今年': 1, '季': 1, '板凳': 1, '席': 1, '總教練': 1, '給': 2, 'Lebron': 1, '對於': 1, '魔術': 1, '耳': 1, '情況': 1, '狀態': 1, '人生': 1, 'Life': 1, '完全': 1, '報導': 1, '經': 2, '事': 1, '書': 3, '溜': 1, '緊繃': 1, '膝傷': 1, '綜合': 1, '記者': 1, '風格': 1, '直言': 1, '心態': 1, 'Dwyane': 1, '中和': 1, '可能': 1, '折磨': 1, '失效': 1, '透露': 1, '飽受': 1, '新書': 1, 'Spoelstra': 6, '除了': 2, '正': 1, '怒火': 2, '所作所為': 1, 'First': 1, '叮嚀': 1, '季後賽': 2, '種會': 1, '送': 1, '身為': 1, '多過': 1, '爭執': 1, '皇帝': 1, '當時': 3, '教練': 3, '電視': 1, '歇斯底里': 1, '衝突': 1, '內幕': 1, '所有': 1, '球迷': 1, 'Bigger': 1, '總是': 1, '好兄弟': 1, '戰時': 1, '有的': 1, '邊': 1, '出書': 1, '比賽': 1, 'Wade': 8, '一直': 1, '教頭': 1, '一些': 1, '表現': 1, 'NBAWade': 1, '憤怒': 1, '看到': 1, '準決賽': 2, '強悍': 1, '澄清': 1, '談到': 1, '時候': 1, 'Van': 2, '炒掉': 1, 'My': 1, '對方': 1, '對罵': 1, '保持': 1, '一樣': 1, '高度': 2, 'Basketball': 1, '談': 1, '發生': 1, '上場': 2, 'Stan': 2, '正好': 1, '簽名書': 1, 'Father': 1, '前': 1, '知': 1, '閃電俠': 1, '面對': 1, '造就': 1, '冠軍': 1, '馬的': 1, '秘辛': 1, '不過': 3, 'Than': 1, '第三': 2, '東區': 1, '畫面': 1, '挫折': 2, '掃': 1, '通常': 1, '潛意識': 1, '特地': 1, '激烈': 1, 'Gundy': 2, '甚至': 1, '試': 1, '程度': 1, '熱火': 3, '策略': 1, '態度': 1, '集中': 1, '戰': 1, '雖然': 1, 'James': 1, '直到': 1, '大談': 1, '透過': 1, '本': 2, '就是': 1, '解釋': 1, '生氣': 2, '爸爸': 2, '魔獸': 1, '大開眼界': 1, '轉播': 1, '破口大罵': 1, '帶': 2, '推出': 1, '那時': 1, '推崇': 1}

# %% [markdown]
# ## 4
# ### build term dictionary  {term:[TF,DF]...}

# %%
term_dict = {}

for i in list(each_doc.keys()):
    for j in list(each_doc[i].keys()):
        if j not in list(term_dict.keys()):
            term_dict[j] = [0, 1]
            term_dict[j][0] += each_doc[i][j]
        else:
            term_dict[j][0] += each_doc[i][j]
            term_dict[j][1] += 1
            
print(term_dict)
# Out:
# {'追晉': [1, 1], '毛治國': [33, 11], '拉姆': [1, 1], '軍地': [9, 1], '八十六學年度': [1, 1], '納智捷': [2, 2], '抹煞': [4, 3], '票勝選': [1, 1], '指定': [20, 12], '嘉年華': [3, 3], 'Rajai': [1, 1], '造': [9, 8], '擦拭': [1, 1], '天賽': [1, 1], '經費': [94, 53], '1.7': [1, 1], '病': [5, 4], '幹': [5, 4], '2005年': [24, 20], '放到': [6, 5], '收歸': [4, 4], '蔡文誠': [1, 1], '叼走': [1, 1], '34.74': [1, 1], '軒然大波': [4, 3], '仍舊': [11, 11], '開放為': [1, 1], '長子': [6, 5], '八大': [14, 10], '現實': [15, 13], '調成': [1, 1], '景觀': [5, 5], '溫和': [10, 8], '費瑞': [1, 1], 'si': [1, 1], '影': [1, 1], '曲棍球': [4, 2], '馬格麗柯特': [2, 2], '助長': [2, 2], '一面倒': [8, 6], '裝填': [7, 4], 'too': [1, 1], '克萊文格': [3, 1], '私心': [1, 1], '熱戀': [1, 1], '一百一十二萬餘': [1, 1], 'move': [1, 1], '贏家': [13, 12], '透納': [3, 1], '興革': [3, 2], 'vs': [11, 10], '轟掉': [1, 1], '繳出': [133, 117], '活寶': [1, 1], '度於': [1, 1], '拉至': [1, 1], 'Musial': [4, 1], 'Day': [1, 1], '不休假': [4, 1], '史潘獎': [7, 1], '驚驚': [1, 1], '預約': [1, 1], '中多': [1, 1], '國務': [7, 5], '封關戰': [3, 3], '罰球線': [19, 12], '大限': [2, 2], '決賽': [125, 61], '曾祖父母': [1, 1], '1.9': [2, 2], 'Dyson': [1, 1], '對方': [81, 65], 'Furcal': [1, 1], '高額': [16, 12], 'DAY': [1, 1], '顧慮': [11, 11], '游走': [2, 2], '郵票': [9, 3], '首獎': [1, 1], '審議權': [1, 1], '中日隊': [3, 2], '16.5': [3, 3], '口氣': [7, 7], '直屬': [2, 2], '昏迷': [1, 1], '走光': [1, 1], '08年': [9, 9], '1983年': [2, 2], 'Romero': [1, 1], '扁子': [1, 1], '局處室': [1, 1], '來瘋': [2, 2], '幹部': [41, 28], '感冒': [13, 11], '邱宜君': [3, 3], '壞處': [1, 1], '娃': [1, 1], '查維茲': [2, 2], '黃四吉': [3, 1], '次助殺': [1, 1], '變': [58, 50], '遺留下': [1, 1], '(20)': [2, 2], 'Lopez': [17, 6], '倒閣': [30, 11], 'How': [1, 1], '帳面': [13, 12], '無償': [1, 1], '炮火': [4, 4], '虎晉': [1, 1], '專長': [13, 8], '總預算': [51, 25], '年終賽': [4, 4], 'Alba': [3, 2], '捨': [3, 3], '艦隊司': [1, 1], '敞開': [3, 3], '來電': [7, 5], '改由': [11, 11], '史代波': [1, 1], 'UNITED': [1, 1], 'Li': [1, 1], '上修': [2, 1], '跑者': [23, 18], '凱': [1, 1], '邀請賽': [4, 4], '老母': [1, 1], '搬入': [1, 1], '九日': [2, 2], '眼淚': [3, 3], '進行': [504, 362], '苗栗市': [1, 1], 'NBAT-Mac': [1, 1], '觀點': [16, 13], '人選': [91, 67], 'Lotas': [1, 1], '全體': [21, 18], '報喜': [1, 1], '九百萬': [1, 1], '結論': [27, 24], '帕森斯昨役': [1, 1], '三月': [20, 16], '替人': [1, 1], '三件事': [3, 1], '園區': [22, 13], '3億6000萬': [2, 1], '貪腐案': [1, 1], '高樹鄉': [1, 1], '菜色': [5, 4], '動武': [1, 1], '六百一十二': [2, 1], '看好度': [1, 1], '南投縣': [11, 8], '三千': [2, 2], '籃網': [88, 29], '勢在必行': [5, 5], '種事': [1, 1], 'Hamiltom': [1, 1], '2.82': [4, 4], '經歷': [39, 39], '餵奶': [1, 1], '句號': [1, 1], '照料': [1, 1], '夠': [97, 83], '聘書': [2, 1], '劉國': [1, 1], '同盟': [2, 2], '舞蹈': [4, 4], '存量': [4, 2], '營建署': [8, 4], '無緣': [31, 29], '3日': [39, 35], '白皮書': [8, 1], 'Strop': [10, 4], '昨天': [674, 432], '陳彥博': [4, 1], '募款王': [1, 1], '把風': [2, 2], '拘束力': [1, 1], '時序': [1, 1], '社會局': [3, 2], '江昭儀': [1, 1], '小吃': [2, 2], '一千二百萬': [1, 1], '時機': [35, 31], '康案': [1, 1], '聚餐': [1, 1], '外長': [7, 6], '貨': [2, 2], 'Fredman': [1, 1], '1877年': [1, 1], '學人': [2, 2], '悶虧': [1, 1], '祝賀': [3, 3], '過分': [1, 1], '3成92': [1, 1], '個獎': [1, 1], 'Inge': [2, 2], 'Austin': [12, 8], '談論': [1, 1], '替': [113, 96], '相抵': [1, 1], '網子': [1, 1], '一○七': [1, 1], '數支': [1, 1], '牛毛': [1, 1], '出走': [6, 6], '技壓達': [1, 1], '逝': [1, 1], '監控': [1, 1], '突圍': [10, 8], '第': [56, 52], '私': [5, 4], '蛇行': [1, 1], 'Rodney': [3, 2], '放肆': [3, 1], '抱怨': [29, 22], 'Nash': [41, 19], '好局': [1, 1], '功拿': [1, 1], '訪陸': [2, 1], '積極面': [1, 1], '辛勞': [10, 7], '衡平': [4, 3], '游泳': [3, 3], '天使': [46, 15], '八千五百點': [1, 1], '連3場': [4, 2], 'Squire/Getty': [2, 1], 'downloading': [1, 1], '包澄治': [2, 1], '航站': [2, 2], '七十三': [1, 1], 'Eddy': [1, 1], '洪璧珍': [1, 1], '交通費': [5, 4], '阿靈頓': [1, 1], '病情': [5, 5], '科威特': [2, 2], '第十八': [6, 4], '化妝': [4, 4], '選前': [20, 10], '敵方': [1, 1], '高地': [1, 1], '人民幣': [1, 1], '百分之十': [1, 1], '全牛': [1, 1], '專家團': [4, 2], '雪上加霜': [7, 7], '八萬九千': [1, 1], '311': [2, 2], '互設': [4, 3], '水都': [1, 1], '5日': [52, 46], '手感火燙': [1, 1], '支紅': [5, 5], '球王史': [1, 1], '敲門磚': [1, 1], '原定': [13, 12], '空洞': [1, 1], '義舉': [1, 1], '台東縣': [2, 2], '專家': [72, 48], '桿洞射鳥': [1 ...

# %% [markdown]
# ## 5
# ### transform term_dict into dataframe  &  calculate IDF, WEIGHT

# %%
import pandas as pd
import numpy as np
term_frame = pd.DataFrame(term_dict).T
term_frame.columns = ['TF', 'DF']
term_frame['IDF'] = np.log10(2000/term_frame['DF'])
term_frame['Weighting'] = term_frame['TF'] * term_frame['IDF']
print(term_frame)
print(term_frame.T['風格'])
# Out:
#                  TF  DF       IDF   Weighting
# #                 7   3  2.823909   19.767361
# #7of              1   1  3.301030    3.301030
# $7                1   1  3.301030    3.301030
# &nbsp           102  33  1.782516  181.816638
# &nbspBaltimore    1   1  3.301030    3.301030
# &nbspKANSAS       1   1  3.301030    3.301030
# (0)               1   1  3.301030    3.301030
# (02)              1   1  3.301030    3.301030
# (1)               3   3  2.823909    8.471726
# (10)              1   1  3.301030    3.301030
# (102)             3   3  2.823909    8.471726
# (11)              3   3  2.823909    8.471726
# (12)              3   3  2.823909    8.471726
# (13)              8   7  2.455932   19.647456
# (14)              3   3  2.823909    8.471726
# (15)              6   6  2.522879   15.137272
# (16)              7   7  2.455932   17.191524
# (17)              9   9  2.346787   21.121087
# (18)              7   7  2.455932   17.191524
# (19)              5   5  2.602060   13.010300
# (2)               5   5  2.602060   13.010300
# (20)              2   2  3.000000    6.000000
# (2008)            1   1  3.301030    3.301030
# (2009)            1   1  3.301030    3.301030
# (2011)            1   1  3.301030    3.301030
# (21)             10  10  2.301030   23.010300
# (22)              7   7  2.455932   17.191524
# (23)             10  10  2.301030   23.010300
# (24)              6   6  2.522879   15.137272
# (25)              7   7  2.455932   17.191524
# ...             ...  ..       ...         ...
# ＩＱ                1   1  3.301030    3.301030
# ＩＳＯ               4   1  3.301030   13.204120
# Ｋ                 6   4  2.698970   16.193820
# ＫＴＶ               3   3  2.823909    8.471726
# ＫＵＳＯ              1   1  3.301030    3.301030
# Ｌ                 2   1  3.301030    6.602060
# ＭＶＰ               3   2  3.000000    9.000000
# Ｎ                 1   1  3.301030    3.301030
# ＮＢＡ               6   2  3.000000   18.000000
# ＮＣＣ              39  10  2.301030   89.740170
# ＮＲＣ               1   1  3.301030    3.301030
# ＮＴＥ               1   1  3.301030    3.301030
# ＯＫ                3   3  2.823909    8.471726
# ＯＬ                1   1  3.301030    3.301030
# ＰＦＩ               2   1  3.301030    6.602060
# ＰＧＳ               2   1  3.301030    6.602060
# ＰＯ                2   1  3.301030    6.602060
# ＰＰＰ               1   1  3.301030    3.301030
# Ｑ                 3   2  3.000000    9.000000
# ＱＥ3               1   1  3.301030    3.301030
# ＲＩＭＰＡＣ            1   1  3.301030    3.301030
# ＳＳＬＴ              3   1  3.301030    9.903090
# ＳＳＴＬ              1   1  3.301030    3.301030
# ＴＩＦＡ             37   8  2.397940   88.723780
# ＴＰＰ              18   8  2.397940   43.162920
# ＵＳＮＲＣ             1   1  3.301030    3.301030
# ＵＳＴＲ              2   1  3.301030    6.602060
# ＶＷＰ               1   1  3.301030    3.301030
# ＷＡＮＯ              2   1  3.301030    6.602060
# ＷＴＯ               6   1  3.301030   19.806180
#
# [35679 rows x 4 columns]
# TF           25.000000
# DF           19.000000
# IDF           2.022276
# Weighting    50.556910
# Name: 風格, dtype: float64

# %% [markdown]
# ## 6
# ### transform each_doc into dataframe  & combine two dataframe

# %%
doc_frame = pd.DataFrame(each_doc)
#replace NA with 0
doc_frame.fillna(0, inplace = True)
#1 代表有出現該term
doc_frame[doc_frame > 0] = 1
final_frame = term_frame.join(doc_frame)
final_frame
print(final_frame.T['風格'])
# Out:
# TF           25.000000
# DF           19.000000
# IDF           2.022276
# Weighting    50.556910
# 1             1.000000
# 2             0.000000
# 3             0.000000
# 4             0.000000
# 5             0.000000
# 6             0.000000
# 7             1.000000
# 8             0.000000
# 9             0.000000
# 10            0.000000
# 11            0.000000
# 12            0.000000
# 13            0.000000
# 14            0.000000
# 15            0.000000
# 16            0.000000
# 17            0.000000
# 18            0.000000
# 19            0.000000
# 20            0.000000
# 21            0.000000
# 22            0.000000
# 23            0.000000
# 24            0.000000
# 25            0.000000
# 26            0.000000
#                ...
# 1971          0.000000
# 1972          0.000000
# 1973          0.000000
# 1974          0.000000
# 1975          0.000000
# 1976          0.000000
# 1977          0.000000
# 1978          0.000000
# 1979          0.000000
# 1980          0.000000
# 1981          0.000000
# 1982          0.000000
# 1983          0.000000
# 1984          0.000000
# 1985          0.000000
# 1986          0.000000
# 1987          0.000000
# 1988          0.000000
# 1989          0.000000
# 1990          0.000000
# 1991          0.000000
# 1992          0.000000
# 1993          0.000000
# 1994          0.000000
# 1995          0.000000
# 1996          0.000000
# 1997          0.000000
# 1998          0.000000
# 1999          0.000000
# 2000          0.000000
# Name: 風格, dtype: float64

# %% [markdown]
# ## 7
# ### add vector columns

# %%
for i in range(1, 2001):
    vector = 'vector_doc{}'.format(i)
    final_frame[vector] = final_frame[i] * final_frame['Weighting']

# %% [markdown]
# ### calculate similarity

# %%
sim = {}
for i in range(1, 2001):
    comparison = 'vector_doc{}'.format(i)
    a = sum(final_frame['vector_doc56'] * final_frame[comparison])
    b = (sum((final_frame['vector_doc56'] ** 2)) ** 0.5) * (sum((final_frame[comparison] ** 2)) ** 0.5)
    sim[i] = a/b
print(sim)
# Out:
# {1: 0.30052437581866209, 2: 0.24948327713198554, 3: 0.42835337108624755, 4: 0.43568712516282448, 5: 0.30364091487712835, 6: 0.34643603035594045, 7: 0.52934609914891062, 8: 0.18253505331350675, 9: 0.37915747559481228, 10: 0.44447363649184179, 11: 0.25421089541699809, 12: 0.37165835748267373, 13: 0.32945578301320277, 14: 0.3271088526294581, 15: 0.40523478129093982, 16: 0.18684209250160164, 17: 0.36380499387838033, 18: 0.30400565283005659, 19: 0.22761376939186057, 20: 0.26178270874135212, 21: 0.36077007479205941, 22: 0.48103034884769658, 23: 0.32275677419093357, 24: 0.22936788476718525, 25: 0.23022293285216938, 26: 0.059834346421444626, 27: 0.22112464189321129, 28: 0.25520812130432924, 29: 0.23631854351141218, 30: 0.17965449163565886, 31: 0.33919626060048319, 32: 0.22628344036854534, 33: 0.39979854427610223, 34: 0.2895308939835432, 35: 0.31044694209555546, 36: 0.35413757184841588, 37: 0.39636296543042598, 38: 0.21099552825276716, 39: 0.33013230087850853, 40: 0.27532551823011381, 41: 0.23719443344999674, 42: 0.26123081205355736, 43: 0.38546652559328221, 44: 0.35392911765611873, 45: 0.32848078690023763, 46: 0.45967648170245018, 47: 0.33578373283831664, 48: 0.38780749677679088, 49: 0.32323724443812751, 50: 0.39460117259603561, 51: 0.37678077908714086, 52: 0.30612582252057113, 53: 0.38269110984509025, 54: 0.3306886283073649, 55: 0.29527175863037564, 56: 1.0, 57: 0.37979852493057348, 58: 0.25479048195494591, 59: 0.3575864066301781, 60: 0.13725953962306831, 61: 0.27404844879407614, 62: 0.39096327593637803, 63: 0.34573540002991704, 64: 0.39389734244228813, 65: 0.25893139037341917, 66: 0.37087448487549907, 67: 0.32131855583533647, 68: 0.058427442215441536, 69: 0.45288595529440578, 70: 0.37753156279823108, 71: 0.48858998723088565, 72: 0.27828190474546044, 73: 0.39127609546313302, 74: 0.37873636348578221, 75: 0.24283556806738715, 76: 0.33253795158932276, 77: 0.3218774917668451, 78: 0.21999930142925866, 79: 0.31494148523785281, 80: 0.42646370279255646, 81: 0.15992478212479391, 82: 0.33114933731116597, 83: 0.17874239381306803, 84: 0.39936480409716335, 85: 0.21420292744047428, 86: 0.34218405375099797, 87: 0.18188828003740565, 88: 0.39785325904917429, 89: 0.35229552929086327, 90: 0.21668090324977146, 91: 0.38357841506546847, 92: 0.29780673770702093, 93: 0.24519004374351247, 94: 0.29241059265195357, 95: 0.46123710336280799, 96: 0.20228031326570453, 97: 0.40480499763515049, 98: 0.30839713208478592, 99: 0.30492081492954598, 100: 0.30606461687928804, 101: 0.14773835519422904, 102: 0.29732627920233423, 103: 0.40565222834432657, 104: 0.34554240003799958, 105: 0.38180110513835386, 106: 0.40243451352057152, 107: 0.21069919027808415, 108: 0.11124706745639733, 109: 0.18187373814962282, 110: 0.45200848135450106, 111: 0.38557682014295058, 112: 0.13891858601017026, 113: 0.16327527163767025, 114: 0.20232282601960627, 115: 0.37581580259832736, 116: 0.30189539624410144, 117: 0.29936711812532674, 118: 0.28248704937934943, 119: 0.27525921500954598, 120: 0.32796083109520779, 121: 0.4217418524886723, 122: 0.3662690317792075, 123: 0.18958028122331977, 124: 0.31068616473826044, 125: 0.38406148103172144, 126: 0.29301789642953141, 127: 0.36884600223145653, 128: 0.37566129250914965, 129: 0.43644564465296765, 130: 0.47729149558014455, 131: 0.25304903439983517, 132: 0.2168896328585791, 133: 0.32025605980487182, 134: 0.21664178736994166, 135: 0.37959849818112046, 136: 0.38902301575329479, 137: 0.2641795870540975, 138: 0.41585648564423244, 139: 0.35141385239148798, 140: 0.36614355201958232, 141: 0.38540195615860412, 142: 0.34586262899431164, 143: 0.39285964119483457, 144: 0.25870678089092891, 145: 0.11202384866493866, 146: 0.25335556934739051, 147: 0.12930800223796873, 148: 0.2304506229451368, 149: 0.18588747668581468, 150: 0.41243215204697276, 151: 0.12314197686760463, 152: 0.43883525563671322, 153: 0.37437227245088578, 154: 0.45697618243556481, 155: 0.19521947391413991, 156: 0.43163570537153817, 157: 0.2053428877306788, 158: 0.15459154795154495, 159: 0.13291252868973591 ...

# %%
import operator
sorted_sim = sorted(sim.items(), key=operator.itemgetter(1), reverse=True)

print(sorted_sim[1:12])
result_sim = sorted_sim[1:12]
# Out:
# [(1275, 0.57323993177683519), (365, 0.55164023313668287), (410, 0.5491866386091443), (1001, 0.54375198902738875), (1408, 0.52999142116105147), (7, 0.52934609914891062), (1026, 0.50948702241500088), (1424, 0.50873166364058686), (438, 0.50446099004264744), (1042, 0.50443277106001594), (341, 0.50389354495074612)]

# %% [markdown]
# ## 8
# ### export sorted_sim into txt file

# %%
final_sim = ["Result Format\n" + "ID Similarity\n"]

for i in result_sim:
    i = str(i[0]) + " " + str(i[1]) + "\n"
    final_sim.append(i)
    
print(final_sim)

file = open("result_sim.txt", "w", encoding = "UTF-8")

for i in final_sim:
    file.write(str(i))   
file.close()
# Out:
# ['Result Format\nID Similarity\n', '1275 0.573239931777\n', '365 0.551640233137\n', '410 0.549186638609\n', '1001 0.543751989027\n', '1408 0.529991421161\n', '7 0.529346099149\n', '1026 0.509487022415\n', '1424 0.508731663641\n', '438 0.504460990043\n', '1042 0.50443277106\n', '341 0.503893544951\n']
